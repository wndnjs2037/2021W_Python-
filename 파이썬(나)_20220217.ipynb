# %% [markdown]
# <a href="https://colab.research.google.com/github/wndnjs2037/2021W_Python-/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC(%EB%82%98)_20220217.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 엑셀파일을 불러주기 위해 버전 맞춰주기

# %%
pip install xlrd==1.2.0

# %%
import pandas as pd

# %%
pd.read_excel('./seoul.xls', header=1, usecols="C:K")
# Out:
#      전체   남학생   여학생  전체.1  남학생.1  여학생.1  전체.2  남학생.2  여학생.2
# 0  35.1  29.8  40.8  25.4   21.2   29.9  11.2    8.8   13.8

# %%
col_names = ['스트레스','스트레스남학생','스트레스여학생','우울감경험률','우울남학생','우울여학생','자살생각율','자살남학생','자살여학생']
col_names
# Out:
# ['스트레스',
#  '스트레스남학생',
#  '스트레스여학생',
#  '우울감경험률',
#  '우울남학생',
#  '우울여학생',
#  '자살생각율',
#  '자살남학생',
#  '자살여학생']

# %%
raw_data = pd.read_excel('./seoul.xls', header=1, usecols="C:K",names=col_names)

# %%
raw_data.loc[1] = 100 - raw_data.loc[0]
raw_data
# Out:
#    스트레스  스트레스남학생  스트레스여학생  우울감경험률  우울남학생  우울여학생  자살생각율  자살남학생  자살여학생
# 0  35.1     29.8     40.8    25.4   21.2   29.9   11.2    8.8   13.8
# 1  64.9     70.2     59.2    74.6   78.8   70.1   88.8   91.2   86.2

# %%
raw_data2 = raw_data.loc[:, '응답']= ['그렇다','아니다'] #콜론을 통해 전체 열을 선택할 수 있다.
raw_data
# Out:
#    스트레스  스트레스남학생  스트레스여학생  우울감경험률  우울남학생  우울여학생  자살생각율  자살남학생  자살여학생   응답
# 0  35.1     29.8     40.8    25.4   21.2   29.9   11.2    8.8   13.8  그렇다
# 1  64.9     70.2     59.2    74.6   78.8   70.1   88.8   91.2   86.2  아니다

# %%
raw_data2 = raw_data.set_index('응답') #응답 열로 인덱스 변경하기
# 변경시, 원본 유지할지 안할지 inplace 키워드로 설정 가능함

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following packages were automatically installed and are no longer required:
#   cuda-command-line-tools-10-0 cuda-command-line-tools-10-1
#   cuda-command-line-tools-11-0 cuda-compiler-10-0 cuda-compiler-10-1
#   cuda-compiler-11-0 cuda-cuobjdump-10-0 cuda-cuobjdump-10-1
#   cuda-cuobjdump-11-0 cuda-cupti-10-0 cuda-cupti-10-1 cuda-cupti-11-0
#   cuda-cupti-dev-11-0 cuda-documentation-10-0 cuda-documentation-10-1
#   cuda-documentation-11-0 cuda-documentation-11-1 cuda-gdb-10-0 cuda-gdb-10-1
#   cuda-gdb-11-0 cuda-gpu-library-advisor-10-0 cuda-gpu-library-advisor-10-1
#   cuda-libraries-10-0 cuda-libraries-10-1 cuda-libraries-11-0
#   cuda-memcheck-10-0 cuda-memcheck-10-1 cuda-memcheck-11-0 cuda-nsight-10-0
#   cuda-nsight-10-1 cuda-nsight-11-0 cuda-nsight-11-1 cuda-nsight-compute-10-0
# ...

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %%
raw_data
# Out:
#    스트레스  스트레스남학생  스트레스여학생  우울감경험률  우울남학생  우울여학생  자살생각율  자살남학생  자살여학생   응답
# 0  35.1     29.8     40.8    25.4   21.2   29.9   11.2    8.8   13.8  그렇다
# 1  64.9     70.2     59.2    74.6   78.8   70.1   88.8   91.2   86.2  아니다

# %%
raw_data2['스트레스'].plot.pie(explode=[0,0.2]) #explode : 쪼개지는 정도

# %%
f, ax = plt.subplots(1,3, figsize=(8,4)) #subplot -> plot 여러개
# ax : 축
# 1행 3열의 plot 공간 생성

raw_data2['스트레스'].plot.pie(explode=[0,0.02], ax=ax[0], autopct='%1.1f%%') # pie 차트를 ax[0]을 통해 0번째 축에 삽입해줌
ax[0].set_title("스트레스를 받은 적 있다") #차트의 제목 추가 가능

raw_data2['우울감경험률'].plot.pie(explode=[0,0.02], ax=ax[1], autopct='%1.1f%%') 
ax[1].set_title("우울증을 경험한 적이 있다") 

raw_data2['자살생각율'].plot.pie(explode=[0,0.02], ax=ax[2], autopct='%1.1f%%') 
ax[2].set_title("자살을 고민한 적이 있다")
# Out:
# Text(0.5, 1.0, '자살을 고민한 적이 있다')

# %%
practice = pd.DataFrame() # 빈 데이터프레임 생성  
practice
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# 딕셔너리를 사용해서 컬럼을 추가해주기
# 딕셔너리 : 키, 벨류로 이루어진 자료형

practice = pd.DataFrame({
    '날짜' :[],
    '운동' :[],
    '양' :[]
})

# %%
# 날짜, 운동, 양에 해당하는 데이터를 입력
practice.loc[0]=['2019-03-01','달리기', 1]
practice
# Out:
#            날짜   운동    양
# 0  2019-03-01  달리기  1.0

# %%
practice.loc[1]=['2019-03-02','걷기',1]
practice.loc[2]=['2019-03-02','달리기',1]
practice.loc[3]=['2019-03-02','뛰기',1]
practice.loc[4]=['2019-03-02','계단오르기',1]
practice.loc[5]=['2019-03-02','걷기',1.5]
practice.loc[6]=['2019-03-02','달리기',1]
practice
# Out:
#            날짜     운동    양
# 0  2019-03-01    달리기  1.0
# 1  2019-03-02     걷기  1.0
# 2  2019-03-02    달리기  1.0
# 3  2019-03-02     뛰기  1.0
# 4  2019-03-02  계단오르기  1.0
# 5  2019-03-02     걷기  1.5
# 6  2019-03-02    달리기  1.0

# %%
practice.to_csv('./practice.csv', encoding='utf-8') #한글을 사용하기 위한 인코딩 타입 지정, 저장할 파일 이름과 확장자 입력

# %%
pd.read_csv('./practice.csv', encoding='utf-8') #저장한 파일 불러오기
# Out:
#    Unnamed: 0          날짜     운동    양
# 0           0  2019-03-01    달리기  1.0
# 1           1  2019-03-02     걷기  1.0
# 2           2  2019-03-02    달리기  1.0
# 3           3  2019-03-02     뛰기  1.0
# 4           4  2019-03-02  계단오르기  1.0
# 5           5  2019-03-02     걷기  1.5
# 6           6  2019-03-02    달리기  1.0

# %%
pd.read_csv('./practice.csv', encoding='utf-8', index_col=0) #0번째 열을 인덱스로 설정
# Out:
#            날짜     운동    양
# 0  2019-03-01    달리기  1.0
# 1  2019-03-02     걷기  1.0
# 2  2019-03-02    달리기  1.0
# 3  2019-03-02     뛰기  1.0
# 4  2019-03-02  계단오르기  1.0
# 5  2019-03-02     걷기  1.5
# 6  2019-03-02    달리기  1.0

# %%
practice.loc[7]=['2019-03-02','걷기',1.5]
practice.loc[8]=['2019-03-02','달리기',1]
practice.loc[9]=['2019-03-02','뛰기',2.5]
practice.loc[10]=['2019-03-02','계단오르기',0.5]
practice
# Out:
#             날짜     운동    양
# 0   2019-03-01    달리기  1.0
# 1   2019-03-02     걷기  1.0
# 2   2019-03-02    달리기  1.0
# 3   2019-03-02     뛰기  1.0
# 4   2019-03-02  계단오르기  1.0
# 5   2019-03-02     걷기  1.5
# 6   2019-03-02    달리기  1.0
# 7   2019-03-02     걷기  1.5
# 8   2019-03-02    달리기  1.0
# 9   2019-03-02     뛰기  2.5
# 10  2019-03-02  계단오르기  0.5

# %%
#피벗테이블 작성
practice.pivot_table(index="운동", aggfunc="sum") #동일한 데이터끼리 합쳐저서(기본값 -> 평균) 테이블 생성됨, 다른 연산을 하고 싶으면 aggfunc 키워드 사용(sum, mean 등)
#판다스는 기본적으로 테이블 연산시 수치데이터가 아닌 경우엔 무시함 (날짜 등)
# Out:
#          양
# 운동
# 걷기     4.0
# 계단오르기  1.5
# 달리기    4.0
# 뛰기     3.5

# %%
# practice2 = practice

# %%
# practice2['기분']='좋다'
# practice2

# %%
# practice2.pivot_table(index='운동') #추가한 기분 데이터는 수치가 아니기 때문에 생략되어 반환된다.

# %%
# practice2['기분']=1
# practice2.pivot_table(index='운동') #수치로 변경해주면 기분 데이터도 나옴

# %%
practice.loc[0] = ['19-3-1', '달리기', 1]
practice.loc[1] = ['19-3-2', '걷기', 1]
practice.loc[2] = ['19-3-2', '달리기', 1]
practice.loc[3] = ['19-3-2', '계단오르기', 1]
practice.loc[4] = ['19-3-3', '걷기', 1.5]
practice.loc[5] = ['19-3-3', '달리기', 1]
practice.loc[6] = ['19-3-4', '걷기', 1.5]
practice.loc[7] = ['19-3-5', '달리기', 1]
practice.loc[8] = ['19-3-6', '걷기', 2.5]
practice.loc[9] = ['19-3-6', '달리기', 0.5]

# %%
import numpy as np
practice.pivot_table(index="운동", aggfunc=['sum', len])
# Out:
#        sum len
#          양  날짜  양
# 운동
# 걷기     6.5   4  4
# 계단오르기  1.5   2  2
# 달리기    4.5   5  5

# %%
practice
# Out:
#             날짜     운동    양
# 0       19-3-1    달리기  1.0
# 1       19-3-2     걷기  1.0
# 2       19-3-2    달리기  1.0
# 3       19-3-2  계단오르기  1.0
# 4       19-3-3     걷기  1.5
# 5       19-3-3    달리기  1.0
# 6       19-3-4     걷기  1.5
# 7       19-3-5    달리기  1.0
# 8       19-3-6     걷기  2.5
# 9       19-3-6    달리기  0.5
# 10  2019-03-02  계단오르기  0.5

# %%
prac_pivot = practice.pivot('날짜','운동','양')
prac_pivot.fillna(0,inplace=True)
prac_pivot

# 에러
#Index contains duplicate entries, cannot reshape - 인덱스와 컬럼이 중복이면 실행 불가 (3/6 걷기 1시간 3/6걷기 2시간 이런식이면 오류남)
# Out:
# 운동           걷기  계단오르기  달리기
# 날짜
# 19-3-1      0.0    0.0  1.0
# 19-3-2      1.0    1.0  1.0
# 19-3-3      1.5    0.0  1.0
# 19-3-4      1.5    0.0  0.0
# 19-3-5      0.0    0.0  1.0
# 19-3-6      2.5    0.0  0.5
# 2019-03-02  0.0    0.5  0.0

# %%
df = pd.read_excel('./exercise.xls')
df.head(5) #보고싶은 데이터의 개수만큼 지정 가능, 뒤에서 지정하고 싶다면 tail 사용
# Out:
#      기간  대분류   분류  ...  운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 0  2019  서울시  서울시  ...      37.3                5.2  1.4
# 1  2019   성별   남자  ...      32.4                4.9  1.1
# 2  2019   성별   여자  ...      41.0                5.4  1.7
# 3  2019  연령별  10대  ...      32.6                3.5    -
# 4  2019  연령별  20대  ...      38.8                6.4  0.1
#
# [5 rows x 9 columns]

# %%
#열 지우기
df = df.drop(columns='기간') #기간 열(column)을 삭제
df.head(1)
# Out:
#    대분류   분류  운동을 할 충분한 시간이 없어서  ...  운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 0  서울시  서울시               46.8  ...      37.3                5.2  1.4
#
# [1 rows x 8 columns]

# %%
#행 지우기
df = df.drop(index=range(22,len(df.index))) #22행부터 마지막행까지의 데이터(index) 삭제
df
# Out:
#       대분류            분류  운동을 할 충분한 시간이 없어서  ...  운동을 싫어해서  운동을 할 충분한 비용이 없어서    기타
# 0     서울시           서울시               46.8  ...      37.3                5.2   1.4
# 1      성별            남자               52.4  ...      32.4                4.9   1.1
# 2      성별            여자               42.5  ...      41.0                5.4   1.7
# 3     연령별           10대               55.3  ...      32.6                3.5     -
# 4     연령별           20대               46.0  ...      38.8                6.4   0.1
# 5     연령별           30대               59.9  ...      27.3                4.5   0.2
# 6     연령별           40대               54.1  ...      35.5                3.3   0.4
# 7     연령별           50대               46.1  ...      36.8                5.6   0.8
# 8     연령별        60대 이상               26.6  ...      48.7                6.6   5.6
# 9     학력별         중졸 이하               24.7  ...      48.6                7.3   8.5
# ...

# %%
# 성별 데이터를 가져오기 위해 데이터가 성별인 행만 남겨준다
df['대분류']=='성별'
# Out:
# 0     False
# 1      True
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# Name: 대분류, dtype: bool

# %%
df = df[df['대분류']=='성별'] #True인 행만 가져오기 위해 True 값만 새로 df에 집어넣음

# %%
df = df.drop(columns='대분류') #대분류 열 삭제

# %%
df
# Out:
#    분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  ...  운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 1  남자               52.4               4.4  ...      32.4                4.9  1.1
# 2  여자               42.5               5.6  ...      41.0                5.4  1.7
#
# [2 rows x 7 columns]
